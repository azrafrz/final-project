# %% [markdown]
# <a href="https://colab.research.google.com/github/azrafrz/final-project/blob/main/Final_Project_Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-generativeai pandas

import pandas as pd
import google.generativeai as genai
from google.colab import files

# %%
from google.colab import userdata
userdata.get('gemini')
genai.configure(api_key="gemini")

# %%
uploaded = files.upload()

csv_path = list(uploaded.keys())[0]
df = pd.read_csv(csv_path)

print("\n✅ File berhasil dimuat!")
print(df.head())
# Out:
#      <input type="file" id="files-c5dad000-c124-4ba7-a48b-d48f6f6a5858" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c5dad000-c124-4ba7-a48b-d48f6f6a5858">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
model = genai.GenerativeModel(
    model_name="gemini-2.5-flash",
    generation_config={
        "temperature": 0.3,
        "max_output_tokens": 512,
        "top_p": 1.0,
        "top_k": 40
    }
)

# %%
def chatbot(query):
    prompt = f"""
    Kamu adalah asisten monitoring Access Point.
    Berikut data Access Point dari dashboard:
    {context_text}

    Berdasarkan data di atas, jawab pertanyaan berikut dengan singkat, jelas, dan berbasis data:
    {query}
    """
    try:
        response = model.generate_content(prompt)
        return response.text.strip()
    except Exception as e:
        return f"⚠️ Terjadi error saat memproses pertanyaan: {str(e)}"

# %%
print("\n🤖 Chatbot siap digunakan! Ketik 'exit' untuk berhenti.\n")

while True:
    user_input = input("User: ")
    if user_input.lower() in ["exit", "quit", "keluar"]:
        print("Chatbot: Sampai jumpa!")
        break
    print("Chatbot:", chatbot(user_input))
# Out:
# 🤖 Chatbot siap digunakan! Ketik 'exit' untuk berhenti.
#
# User: ruangan mana yang memiliki user paling banyak?
# Chatbot: Aula Gedung A memiliki user paling banyak, dengan 30 user.
# User: berapa total seluruh user yang terkoneksi?
# Chatbot: Total seluruh user yang terkoneksi adalah **99**.
# User: access point mana saja yang offline?
# Chatbot: Berikut adalah Access Point yang offline:
# *   AP_Lab2
# *   AP_Lab3
# *   AP_Warehouse
# User: exit
# Chatbot: Sampai jumpa!
